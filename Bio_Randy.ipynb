# %% [markdown]
# # Bio for Randy Betancourt

# %% [markdown]
# My professional career has been in and around data analysis.  My journey began by managing a technical support group supporting over 2,000 technical research analysts and scientists from the U.S. Environmental Protection Agency at one of the largest mainframe complexes run by the federal government.
#
# I moved to Duke University working for the administration to analyze staff resource utilization and costs.  There I was introduced to the politics of data access since the medical school had most of the data and compute resources.
#
# I spent the majority of my career at SAS Institute Inc. where I had the opportunity to perform numerous roles, starting in marketing and later moving into field enablement and product management.  I subsequently developed the role for Office of the CTO consultant.
# I literally traveled the globe meeting with IT and business leaders discussing the impacts data analysis can have to drive the business.  And we also discussed challenges they faced.  At the same time, I spent time with end users—wanting to hear their perspective.  Together these experiences shaped my understanding of trade-offs businesses make allocating scarce resources to data collection, analysis, and deployment of models.
#
# More recently I worked with the International Institute of Analytics helping to deliver their analytical maturity assessment services.  The goals are to quantify and rank a firm’s data analysis abilities among their peer group accompanied by a set of candidate projects (and justifications) designed to grow these capabilities.
#
# Throughout my entire career I have marveled at the intellectual capacity and inventiveness of those I have met.   The continuous cycles of innovation make this domain as interesting as it was for me on the day I began my journey.

# %%
from IPython.display import Image
Image(filename='Anaconda3\\output\\trb_utah.JPG')
